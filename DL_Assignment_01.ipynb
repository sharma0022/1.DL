# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshkumar145/DL_Theory/blob/main/DL_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.	What is the function of a summation junction of a neuron? What is threshold activation function?**
#
# **Ans:** A summation junction is used as linear combiner of the weigthed input signals.
#
# A threshold activation function results in an output signal only when an input signal exceeding a specific threshold value comes as an input. It is similar in behaviour to the biological neuron which transmits the signal only when the total input signal meets the firing threshold.

# %% [markdown]
# **2.	What is a step function? What is the difference of step function with threshold function?**
#
# **Ans:** In step function the output ranges between 0 to 1 i.e., binary.the output assumes value 0 for negative argument and 1 for positive argument.
#
# Step function with thershold is a threshold-based activation function which means after a certain threshold neuron is activated and below the said threshold neuron is deactivated.

# %% [markdown]
# **3.	Explain the McCulloch–Pitts model of neuron.**
#
# **Ans:** In McCulloch–Pitt neural network the neurons are connected by directed weighted paths. This allows binary activation i.e.,either with 1 it activate or with 0 it gets deactivited.

# %% [markdown]
# **4.	Explain the ADALINE network model?**
#
# **Ans:** Adline is  adaptive linear neuron which is a linear activation function .It uses the delta rule for training to minimize the mean squared errors between the actual output and the desired target output. The weights and bias are adjustable

# %% [markdown]
# **5.	What is the constraint of a simple perceptron? Why it may fail with a real-world data set?**
#
# **Ans:** Output of a perceptron is binary number. So it can only be used to classify the linearly separable sets of input vectors. If the input vectors are non-linear, it is not easy to classify them correctly.Because of its linearity it will fail in real world data set.

# %% [markdown]
# **6.	What is linearly inseparable problem? What is the role of the hidden layer?**
#
# **Ans:** If a line or hyper plane that can separate points into two classes, then the data is separable problem if not it is inseparable problem.
# Hidden Layers are intermediate layers between the input and output layer which process the data by applying complex non-linear functions to them.

# %% [markdown]
# **7.	Explain XOR problem in case of a simple perceptro?**
#
# **Ans:** The XOR problem with neural networks can be solved by using Multi-Layer Perceptrons or a neural network architecture with an input layer, hidden layer, and output layer. This is used to solve XOR logical problems.

# %% [markdown]
# **8.	Design a multi-layer perceptron to implement A XOR ?**
#
# **Ans:** ![1_qA_APGgbbh0QfRNsRyMaJg.png](data:image/png;base64,...)

# %% [markdown]
# **9.	Explain the single-layer feed forward architecture of ANN?**
#
# **Ans:** The input layer is connected to the output layer nodes with weights. All the input nodes are connected to each of the output nodes. The term feed-forward depicts that there is no feedback sent from the output layer to the input layer.

# %% [markdown]
# **10.	Explain the competitive network architecture of ANN?**
#
# **Ans:** ANN consists of three or more layers. The first layer is the input layer. It contains the input neurons that send information to the hidden layer. The hidden layer performs the computations on input data and transfers the output to the output layer.

# %% [markdown]
# **11.	Consider a multi-layer feed forward neural network. Enumerate and explain steps in the backpropagation algorithm used to train the network?**
#
# **Ans:** Back propagation computes the gradient of the loss function for a single weight by the chain rule. It efficiently computes one layer at a time.. It computes the gradient, but it does not define how the gradient is used. It generalizes the computation in the delta rule.
#
# **STEPS:**
#
# 1.Inputs arrive through the preconnected path
#
# 2.Input is modeled using real weights W. The weights are usually randomly selected.
#
# 3.Calculate the output for every neuron from the input layer, to the hidden layers, to the output layer.
#
# 4.Calculate the error in the outputs.
# **Error= Actual Output – Desired Output**
#
# 5.Travel back from the output layer to the hidden layer to adjust the weights such that the error is decreased.

# %% [markdown]
# **12.	What are the advantages and disadvantages of neural networks?**
#
# **Ans:**
#
# **Advantages:**
#
# 1.A neural network can implement tasks that a linear program cannot.
#
# 2.When an item of the neural network declines, it can continue without some issues by its parallel features.
#
# 3.A neural network determines and does not require to be reprogrammed.
#
#
# **Disadvantages:**
#
# 1.The neural network required training to operate.
#
# 2.It needed high processing time for big neural networks.
#
# 3.Does not explain the internal relation between data.

# %% [markdown]
# **13.	Write short notes on any two of the following:**
#
# **1.	Biological neuron**
#
# A biological neural network is a network of neurons that are connected together by axons and dendrites. The connections between neurons are made by synapses
#
# **2.	ReLU function**
#
# ReLU is a piecewise linear function that will give output to input directly if it is positive, otherwise, it will output zero.
#
# **3.	Single-layer feed forward ANN**
#
# The input layer is connected to the output layer nodes with weights. All the input nodes are connected to each of the output nodes. The term feed-forward depicts that there is no feedback sent from the output layer to the input layer.
#
# **4.	Gradient descent**
#
# Gradient Descent is used to solves optimization problems using first-order iterations. Since it is designed to find the local minimum of a differential function, gradient descent is widely used in machine learning models to find the best parameters that minimize the model's cost function.
#
# **5.	Recurrent networks**
#
# RNN is a type of Neural Network where the output from the previous step are fed as input to the current step. In traditional neural networks, all the inputs and outputs are independent of each other, but in cases like when it is required to predict the next word of a sentence, the previous words are required and hence there is a need to remember the previous words.
